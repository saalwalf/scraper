# %%
import requests
import json
import pandas as pd

# %%
url = "https://instagram-scraper-api2.p.rapidapi.com/v1/likes"

querystring = {"code_or_id_or_url":"instagram.com/p/CxYQJO8xuC6"}

headers = {
	"x-rapidapi-key": "560df90893msh1e3676ab3bc51c5p1b4ccejsn8c5479d1cfa2",
	"x-rapidapi-host": "instagram-scraper-api2.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

# %%
response = response.json()

# %%
data = pd.DataFrame(response['data']['items'])
data
# Out:
#                     full_name           id  is_new  is_private  is_verified  \
# 0              Sorgen Ismaili   2023031682   False        True        False
# 1                 حمزه الديري  69525691616   False       False        False
# 2                    डॉन थेटे   5786984712   False       False        False
# 3                              69611411947   False        True        False
# 4              mehdieghbali72  50440526726   False        True        False
# ..                        ...          ...     ...         ...          ...
# 854  mohammad ali khalildokht   4037324613   False       False        False
# 855                    hosein  57266343515   False       False        False
# 856                  Samir ✨🤍  62109528739   False       False        False
# 857                       dev  50724812882   False       False        False
# 858                     Vijay  61791675821   False        True        False
#
#      latest_reel_media       profile_pic_id  \
# 0                    0  2169256910174544301
# 1           1728111489  3470924301541186247
# 2                    0  3281361182944225818
# 3                    0                  NaN
# 4                    0  2704436882463306909
# ..                 ...                  ...
# 854                  0  3431780284464917222
# 855                  0  3231544896726795284
# 856                  0  3459347808317766094
# 857                  0  3306512110099848692
# 858                  0  3396767452532259926
#
#                                        profile_pic_url           username
# 0    https://scontent-qro1-2.cdninstagram.com/v/t51...     ismaili_sorgen
# 1    https://scontent-qro1-1.cdninstagram.com/v/t51...     hamza.aldere27
# 2    https://scontent-qro1-2.cdninstagram.com/v/t51...  bharat_thete_1111
# 3    https://instagram.fusq1-1.fna.fbcdn.net/v/t51....          alanpuri1
# 4    https://scontent-qro1-1.cdninstagram.com/v/t51...     mehdieghbali72
# ..                                                 ...                ...
# 854  https://scontent-qro1-2.cdninstagram.com/v/t51...  mohammad_ali_200_
# 855  https://scontent-qro1-1.cdninstagram.com/v/t51...        hosein11136
# 856  https://scontent-qro1-2.cdninstagram.com/v/t51...   _.unfav._saimmmm
# 857  https://scontent-qro1-2.cdninstagram.com/v/t51...        _zindabaad_
# 858  https://scontent-qro1-2.cdninstagram.com/v/t51...      mr_vijay_0977
#
# [859 rows x 9 columns]
